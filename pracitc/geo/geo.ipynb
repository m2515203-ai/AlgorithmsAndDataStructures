# %%
import pandas as pd


from pracitc.geo.function import calculate_distances, show_distant, show_speed, calculate_direction

df1 = pd.read_csv('data_01.csv')
df2 = pd.read_csv('data_02.csv')
df3 = pd.read_csv('data_03.csv')
df4 = pd.read_csv('data_04.csv')

df1['distant'] = calculate_distances(df1)
df2['distant'] = calculate_distances(df2)
df3['distant'] = calculate_distances(df3)
df4['distant'] = calculate_distances(df4)

df1['speed'] = calculate_distances(df1)
df2['speed'] = calculate_distances(df2)
df3['speed'] = calculate_distances(df3)
df4['speed'] = calculate_distances(df4)

df1['direction'] = calculate_direction(df1)
df2['direction'] = calculate_direction(df2)
df3['direction'] = calculate_direction(df3)
df4['direction'] = calculate_direction(df4)
datasets = [df1, df2, df3, df4]

# %%
show_distant([df1])
show_distant([df2])
show_distant([df3])
show_distant([df4])
show_distant(datasets)

# %%
show_speed([df1])
show_speed([df2])
show_speed([df3])
show_speed([df4])
show_speed(datasets)

# %%
from pracitc.geo.function import show_direction

show_direction([df1])
show_direction([df2])
show_direction([df3])
show_direction([df4])
show_direction(datasets)

# %%
print(f"\nОбщее пройденное расстояние: df 1 {df1['distant'].sum():.2f} метров")
print(f"\nОбщее пройденное расстояние: df 2 {df2['distant'].sum():.2f} метров")
print(f"\nОбщее пройденное расстояние: df 3 {df3['distant'].sum():.2f} метров")
print(f"\nОбщее пройденное расстояние: df 4 {df4['distant'].sum():.2f} метров")

print(f"\nМаксимальная скорость: df 1 {df1['speed'].max():.2f} метров")
print(f"\nМаксимальная скорость: df 2 {df2['speed'].max():.2f} метров")
print(f"\nМаксимальная скорость: df 3 {df3['speed'].max():.2f} метров")
print(f"\nМаксимальная скорость: df 4 {df4['speed'].max():.2f} метров")

print(f"\nМинимальная скорость: df 1 {df1['speed'].min():.2f} метров")
print(f"\nМинимальная скорость: df 2 {df2['speed'].min():.2f} метров")
print(f"\nМинимальная скорость: df 3 {df3['speed'].min():.2f} метров")
print(f"\nМинимальная скорость: df 4 {df4['speed'].min():.2f} метров")

print(f"\nСредняя скорость: df 1 {df1['speed'].mean():.2f} метров")
print(f"\nСредняя скорость: df 2 {df2['speed'].mean():.2f} метров")
print(f"\nСредняя скорость: df 3 {df3['speed'].mean():.2f} метров")
print(f"\nСредняя скорость: df 4 {df4['speed'].mean():.2f} метров")
# Out:
# Общее пройденное расстояние: df 1 0.00 метров
#
# Общее пройденное расстояние: df 2 156006.44 метров
#
# Общее пройденное расстояние: df 3 41537.79 метров
#
# Общее пройденное расстояние: df 4 1282114.05 метров
#
# Максимальная скорость: df 1 0.00 метров
#
# Максимальная скорость: df 2 29162.20 метров
#
# Максимальная скорость: df 3 14447.98 метров
#
# Максимальная скорость: df 4 6074.54 метров
#
# Минимальная скорость: df 1 0.00 метров
#
# Минимальная скорость: df 2 0.00 метров
#
# Минимальная скорость: df 3 0.00 метров
#
# Минимальная скорость: df 4 0.00 метров
#
# Средняя скорость: df 1 0.00 метров
#
# Средняя скорость: df 2 270.38 метров
#
# Средняя скорость: df 3 182.18 метров
#
# Средняя скорость: df 4 351.07 метров
