# %%
import pandas as pd

df_zap = pd.read_csv('zap_data_22.csv')
df_calib = pd.read_csv('calib.csv')

print(df_zap)
print(df_calib)
# Out:
#               lat        lon   timestamp  speed  voltage  \
# 0             NaN        NaN  1704056413    NaN    25.20
# 1             NaN        NaN  1704056636    NaN    25.20
# 2             NaN        NaN  1704056661    NaN    25.20
# 3             NaN        NaN  1704056751    NaN    25.20
# 4             NaN        NaN  1704056727    NaN    25.20
# ...           ...        ...         ...    ...      ...
# 161529  56.070923  37.123569  1735678101    0.0    25.35
# 161530  56.070923  37.123569  1735678251    0.0    25.35
# 161531  56.070923  37.123569  1735678401    0.0    25.35
# 161532  56.070923  37.123569  1735678551    0.0    25.35
# 161533  56.070923  37.123569  1735678700    0.0    25.35
#
#                                                  can_data
# 0                        {"LLS_0": 1477, "xLLS_71": 1477}
# 1                        {"LLS_0": 1477, "xLLS_71": 1477}
# 2                        {"LLS_0": 1477, "xLLS_71": 1477}
# 3                        {"LLS_0": 1477, "xLLS_71": 1477}
# 4                        {"LLS_0": 1477, "xLLS_71": 1477}
# ...                                                   ...
# 161529  {"3": 56.0709228515625, "4": 37.12356948852539...
# 161530  {"3": 56.0709228515625, "4": 37.12356948852539...
# 161531  {"3": 56.0709228515625, "4": 37.12356948852539...
# 161532  {"3": 56.0709228515625, "4": 37.12356948852539...
# 161533  {"3": 56.0709228515625, "4": 37.12356948852539...
#
# [161534 rows x 6 columns]
#     id  deviceid_port                                   calibrating_data
# 0  450              2  [{"input_value": 500, "output_value": 0}, {"in...
# 1  537              3  [{"input_value": 1, "output_value": 0}, {"inpu...

# %%
import json
# Извлекаем калибровочные данные
calib_data = json.loads(df_calib['calibrating_data'].iloc[0])
print(calib_data)
# Предполагаем, что в JSON есть массивы x (показания датчика) и y (литры)
x = []
y = []
for cur in calib_data:
    x.append(cur['input_value'])
    y.append(cur['output_value'])

print(x)
# Создаем функцию интерполяции
from scipy import interpolate
f = interpolate.interp1d(x, y, fill_value='extrapolate')
# Out:
# [{'input_value': 500, 'output_value': 0}, {'input_value': 516, 'output_value': 10}, {'input_value': 579, 'output_value': 30}, {'input_value': 643, 'output_value': 50}, {'input_value': 706, 'output_value': 70}, {'input_value': 770, 'output_value': 90}, {'input_value': 832, 'output_value': 110}, {'input_value': 908, 'output_value': 130}, {'input_value': 989, 'output_value': 150}, {'input_value': 1072, 'output_value': 170}, {'input_value': 1159, 'output_value': 190}, {'input_value': 1249, 'output_value': 210}, {'input_value': 1343, 'output_value': 230}, {'input_value': 1439, 'output_value': 250}, {'input_value': 1539, 'output_value': 270}, {'input_value': 1647, 'output_value': 290}, {'input_value': 1757, 'output_value': 310}, {'input_value': 1875, 'output_value': 330}]
# [500, 516, 579, 643, 706, 770, 832, 908, 989, 1072, 1159, 1249, 1343, 1439, 1539, 1647, 1757, 1875]

# %%
import matplotlib.pyplot as plt
from scipy import interpolate
import numpy as np
import json

# Сначала преобразуем строковые представления словарей в реальные словари Python
df_zap['data'] = df_zap['can_data'].apply(lambda x: json.loads(x))

# Теперь создаем новый столбец LLS, извлекая значение LLS_0
df_zap['LLS'] = df_zap['data'].apply(lambda x: x.get('LLS_0'))

df_zap['LITRS'] = df_zap['LLS'].apply(lambda x: f(x))

# Если нужно, можно удалить промежуточный столбец data
df_zap.drop(columns=['data'], inplace=True)
df_zap.drop(columns=['can_data'], inplace=True)

df_zap['date'] = pd.to_datetime(df_zap['timestamp'], unit='s')

print(df_zap)
print(df_zap.describe())
# Out:
#               lat        lon   timestamp  speed  voltage     LLS       LITRS  \
# 0             NaN        NaN  1704056413    NaN    25.20  1477.0  257.600000
# 1             NaN        NaN  1704056636    NaN    25.20  1477.0  257.600000
# 2             NaN        NaN  1704056661    NaN    25.20  1477.0  257.600000
# 3             NaN        NaN  1704056751    NaN    25.20  1477.0  257.600000
# 4             NaN        NaN  1704056727    NaN    25.20  1477.0  257.600000
# ...           ...        ...         ...    ...      ...     ...         ...
# 161529  56.070923  37.123569  1735678101    0.0    25.35  3345.0  579.152542
# 161530  56.070923  37.123569  1735678251    0.0    25.35  3345.0  579.152542
# 161531  56.070923  37.123569  1735678401    0.0    25.35  3345.0  579.152542
# 161532  56.070923  37.123569  1735678551    0.0    25.35  3345.0  579.152542
# 161533  56.070923  37.123569  1735678700    0.0    25.35  3345.0  579.152542
#
#                       date
# 0      2023-12-31 21:00:13
# 1      2023-12-31 21:03:56
# 2      2023-12-31 21:04:21
# 3      2023-12-31 21:05:51
# 4      2023-12-31 21:05:27
# ...                    ...
# 161529 2024-12-31 20:48:21
# 161530 2024-12-31 20:50:51
# 161531 2024-12-31 20:53:21
# 161532 2024-12-31 20:55:51
# 161533 2024-12-31 20:58:20
#
# [161534 rows x 8 columns]
#                  lat            lon     timestamp          speed  \
# count  158768.000000  158768.000000  1.615340e+05  158768.000000
# mean       56.071314      37.118455  1.720763e+09       0.049147
# min        56.057796      37.105957  1.704056e+09       0.000000
# 25%        56.071079      37.116344  1.712852e+09       0.000000
# 50%        56.071312      37.116581  1.720080e+09       0.000000
# 75%        56.071550      37.122860  1.730394e+09       0.000000
# max        56.076244      37.131790  1.735679e+09      11.000000
# std         0.000493       0.003427  9.843829e+06       0.348707
#
#              voltage            LLS          LITRS  \
# count  161267.000000  120613.000000  120613.000000
# mean       24.432740    2166.319883     371.943026
# min         0.000000       0.000000    -312.500000
# 25%        25.350000    1401.000000     242.083333
# 50%        25.800000    2090.000000     366.440678
# 75%        27.300000    2983.000000     517.796610
# max        35.700000   65535.000000   11119.830508
# std         6.622768    1086.216903     192.774997
#
#                                 date
# count                         161534
# mean   2024-07-12 05:43:29.664603136
# min              2023-12-31 21:00:13
# 25%    2024-04-11 16:11:07.249999872
# 50%              2024-07-04 08:04:47
# 75%       2024-10-31 17:04:57.500000
# max              2024-12-31 20:58:20
# std                              NaN

# %%
df_cleaned = df_zap.dropna().copy()
print("После удаления строк с NaN:")
print(df_cleaned)
print(df_cleaned.describe())
# Out:
# После удаления строк с NaN:
#               lat        lon   timestamp  speed  voltage     LLS       LITRS  \
# 117     56.071346  37.116501  1704063741    0.0    25.05  1477.0  257.600000
# 118     56.071346  37.116501  1704063631    0.0    25.05  1477.0  257.600000
# 123     56.071346  37.116501  1704063741    0.0    25.05  1477.0  257.600000
# 124     56.071346  37.116501  1704063631    0.0    25.05  1477.0  257.600000
# 128     56.071346  37.116501  1704063631    0.0    25.05  1477.0  257.600000
# ...           ...        ...         ...    ...      ...     ...         ...
# 161529  56.070923  37.123569  1735678101    0.0    25.35  3345.0  579.152542
# 161530  56.070923  37.123569  1735678251    0.0    25.35  3345.0  579.152542
# 161531  56.070923  37.123569  1735678401    0.0    25.35  3345.0  579.152542
# 161532  56.070923  37.123569  1735678551    0.0    25.35  3345.0  579.152542
# 161533  56.070923  37.123569  1735678700    0.0    25.35  3345.0  579.152542
#
#                       date
# 117    2023-12-31 23:02:21
# 118    2023-12-31 23:00:31
# 123    2023-12-31 23:02:21
# 124    2023-12-31 23:00:31
# 128    2023-12-31 23:00:31
# ...                    ...
# 161529 2024-12-31 20:48:21
# 161530 2024-12-31 20:50:51
# 161531 2024-12-31 20:53:21
# 161532 2024-12-31 20:55:51
# 161533 2024-12-31 20:58:20
#
# [118326 rows x 8 columns]
#                  lat            lon     timestamp          speed  \
# count  118326.000000  118326.000000  1.183260e+05  118326.000000
# mean       56.071339      37.118084  1.719075e+09       0.042856
# min        56.068977      37.105957  1.704064e+09       0.000000
# 25%        56.071201      37.116314  1.709343e+09       0.000000
# 50%        56.071331      37.116554  1.717854e+09       0.000000
# 75%        56.071583      37.121460  1.729570e+09       0.000000
# max        56.076244      37.127850  1.735679e+09      11.000000
# std         0.000362       0.003145  9.960114e+06       0.328795
#
#              voltage            LLS          LITRS  \
# count  118326.000000  118326.000000  118326.000000
# mean       25.972191    2176.142496     373.626083
# min         0.000000       0.000000    -312.500000
# 25%        25.350000    1414.000000     244.791667
# 50%        25.650000    2102.000000     368.474576
# 75%        27.300000    2994.000000     519.661017
# max        35.700000   65535.000000   11119.830508
# std         1.990989    1091.656569     193.730776
#
#                                 date
# count                         118326
# mean   2024-06-22 16:57:35.643730176
# min              2023-12-31 23:00:31
# 25%    2024-03-02 01:21:58.249999872
# 50%              2024-06-08 13:38:21
# 75%       2024-10-22 04:11:00.500000
# max              2024-12-31 20:58:20
# std                              NaN

# %%
import datetime

print(df_cleaned[df_cleaned['date'] > datetime.datetime(2024, 10, 1)])
# Out:
#               lat        lon   timestamp  speed  voltage     LLS       LITRS  \
# 105874  56.071388  37.116543  1727936432    0.0    27.60  1113.0  179.425287
# 105875  56.071388  37.116543  1727936581    0.0    27.75  1110.0  178.735632
# 105876  56.071388  37.116543  1727936731    0.0    27.75  1123.0  181.724138
# 105877  56.071388  37.116543  1727936881    0.0    27.75  1121.0  181.264368
# 105878  56.071388  37.116543  1727936950    0.0    27.75  1120.0  181.034483
# ...           ...        ...         ...    ...      ...     ...         ...
# 161529  56.070923  37.123569  1735678101    0.0    25.35  3345.0  579.152542
# 161530  56.070923  37.123569  1735678251    0.0    25.35  3345.0  579.152542
# 161531  56.070923  37.123569  1735678401    0.0    25.35  3345.0  579.152542
# 161532  56.070923  37.123569  1735678551    0.0    25.35  3345.0  579.152542
# 161533  56.070923  37.123569  1735678700    0.0    25.35  3345.0  579.152542
#
#                       date
# 105874 2024-10-03 06:20:32
# 105875 2024-10-03 06:23:01
# 105876 2024-10-03 06:25:31
# 105877 2024-10-03 06:28:01
# 105878 2024-10-03 06:29:10
# ...                    ...
# 161529 2024-12-31 20:48:21
# 161530 2024-12-31 20:50:51
# 161531 2024-12-31 20:53:21
# 161532 2024-12-31 20:55:51
# 161533 2024-12-31 20:58:20
#
# [33813 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df_cleaned['timestamp'].head(2000), df_cleaned['LITRS'].head(2000))
plt.xlabel('time')  #Подпись для оси х
plt.ylabel('LITRS')  #Подпись для оси y
plt.show()


plt.plot(df_cleaned['timestamp'].head(2000), df_cleaned['speed'].head(2000))
plt.xlabel('time')
plt.ylabel('km h')
plt.show()

plt.plot(df_cleaned['timestamp'].head(2000), df_cleaned['voltage'].head(2000))
plt.xlabel('time')
plt.ylabel('km h')
plt.show()

# %%
def calculate(data):
    upper = [None]
    for i in range(1, len(data) - 1):
        current = data.iloc[i]
        prev = data.iloc[i - 1]
        next = data.iloc[i + 1]
        if current["LITRS"] - 10 > prev["LITRS"] or next["LITRS"] - 10 > current["LITRS"]:
            upper.append(True)
        else:
            upper.append(False)

    upper.append(False)
    return upper


def show_full_grafic(data):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['LITRS'], color='blue', linewidth=2, label='LITRS')
    for i in range(len(data)):
        if data['UPPER'].iloc[i] == True:
            plt.axvline(x=data.index[i], color='red', alpha=0.3, linewidth=1,
                        label='UPPER = True' if i == 0 else "")
    plt.xlabel('Индекс')
    plt.ylabel('LITRS')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

df = df_zap.dropna().head(2000).copy()


def find_upper(df):
    df['UPPER'] = None
    df.loc[:, 'UPPER'] = calculate(df)
    show_full_grafic(df)


find_upper(df)
